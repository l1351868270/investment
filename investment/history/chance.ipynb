# %% [markdown]
# 2012.12.05
# 十八大：2012年11月8至2012年11月14日，十八大召开。换届选举。经过一系列传闻后，尘埃落定。2012年12月05日，A股见底。

# %%
import os
import pandas as pd
import mplfinance as mpf

# %% [markdown]
# 上证指数

# %%
daily = pd.read_csv(os.path.abspath('./data/szzs.csv'),index_col=0,parse_dates=True)
daily.index.name = 'Date'
print(daily.shape)
print(daily.head(3))
print(daily.tail(3))
# begin_day = pd.Period('2012-1-1', freq='D')
# end_day = pd.Period('2013-3-1', freq='D')

mpf.plot(daily['2012-6-1': '2013-6-1'], type='candle')
# Out:
# (7906, 5)
#               Open    High     Low   Close  Volume
# Date
# 1990-12-19   96.05   99.98   95.79   99.98    1260
# 1990-12-20  104.30  104.39   99.98  104.39     197
# 1990-12-21  109.07  109.13  103.73  109.13      28
#                Open     High      Low    Close     Volume
# Date
# 2023-04-26  3255.22  3277.98  3239.99  3264.10  357917856
# 2023-04-27  3256.23  3299.30  3253.11  3285.88  341590528
# 2023-04-28  3283.12  3324.88  3283.12  3323.27  401554785

# %%
daily = pd.read_csv(os.path.abspath('./data/cybzs.csv'),index_col=0,parse_dates=True)
daily.index.name = 'Date'
print(daily.shape)
print(daily.head(3))
print(daily.tail(3))
# begin_day = pd.Period('2012-1-1', freq='D')
# end_day = pd.Period('2013-3-1', freq='D')

mpf.plot(daily['2012-6-1': '2013-6-1'], type='candle')
# Out:
# (3138, 5)
#                Open     High     Low   Close   Volume
# Date
# 2010-06-01   986.02   994.79  948.12  973.23  1356285
# 2010-06-02   967.78   997.29  952.78  997.29  1074628
# 2010-06-03  1002.53  1026.88  997.95  998.57  1616805
#                Open     High      Low    Close     Volume
# Date
# 2023-04-26  2764.81  2819.81  2764.81  2801.94  167820384
# 2023-04-27  2786.05  2816.37  2784.84  2799.12  159029280
# 2023-04-28  2796.32  2850.14  2796.32  2848.99  167719497
